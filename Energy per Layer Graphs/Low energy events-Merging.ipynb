# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading the functions I defined in the previous Jupyter notebook
from Functions import EnergyPlotter, PionCorrector

# %%
#Loading low energy data I labeled with ele_low and pion_low
df_low_energy = pd.read_csv("df_low_energy.csv")

# %%
df_low_energy.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df_low_energy
# Out:
#          Layer1     Layer2     Layer3     Layer4     Layer5      Layer6  \
# 0     19.954700  52.775200  101.59100  137.79800  234.91300  188.128000
# 1     71.055100  70.611600  122.13000  142.44600  216.07100  221.751000
# 2    251.631000  51.294700  126.19600  147.27600  121.49000   89.900500
# 3    181.717000  20.926400   47.59130  111.79400  188.02100  175.041000
# 4    336.465000  20.028000   40.28330   44.23950  101.52500  145.443000
# ..          ...        ...        ...        ...        ...         ...
# 195    2.613890   1.380710    1.98295    1.42561    1.35926    0.924484
# 196   17.390600   2.125950    1.79228    7.22561    1.39931    0.885034
# 197    4.061350   3.124930   65.19330   62.19830  108.39000  101.646000
# 198    3.641460  20.570000   47.81320   58.24720  116.43600   64.835100
# 199    0.949095   0.858898    2.88518    1.21051   13.40190    0.000000
#
#       Layer7     Layer8     Layer9    Layer10  ...   Layer33   Layer34  \
# ...

# %%
#Checking shower shapes

# %%
EnergyPlotter(df_low_energy)

# %%
bad_ele_list= [7, 9, 52]
bad_pion_list = [103, 137, 142, 147, 145, 159, 161, 174]

# %%
df_low_energy.drop(bad_ele_list, axis=0, inplace=True)

# %%
df_low_energy.drop(bad_pion_list, axis=0, inplace=True)

# %%
df_low_energy
# Out:
#          Layer1     Layer2     Layer3     Layer4     Layer5      Layer6  \
# 0     19.954700  52.775200  101.59100  137.79800  234.91300  188.128000
# 1     71.055100  70.611600  122.13000  142.44600  216.07100  221.751000
# 2    251.631000  51.294700  126.19600  147.27600  121.49000   89.900500
# 3    181.717000  20.926400   47.59130  111.79400  188.02100  175.041000
# 4    336.465000  20.028000   40.28330   44.23950  101.52500  145.443000
# ..          ...        ...        ...        ...        ...         ...
# 195    2.613890   1.380710    1.98295    1.42561    1.35926    0.924484
# 196   17.390600   2.125950    1.79228    7.22561    1.39931    0.885034
# 197    4.061350   3.124930   65.19330   62.19830  108.39000  101.646000
# 198    3.641460  20.570000   47.81320   58.24720  116.43600   64.835100
# 199    0.949095   0.858898    2.88518    1.21051   13.40190    0.000000
#
#       Layer7     Layer8     Layer9    Layer10  ...   Layer33   Layer34  \
# ...

# %%
new_ele_events = pd.read_csv("run_441_new.csv")

# %%
new_ele_events
# Out:
#      Layer1     Layer2    Layer3    Layer4     Layer5     Layer6     Layer7  \
# 0  174.2510   54.22270   35.1584   83.3848  188.14600  229.83100  285.80700
# 1   10.7035   37.76700  110.5250  128.3180  152.58000  172.04200  135.68200
# 2   32.0040   30.50470   33.8321   33.3245   52.18660   19.96570   40.46860
# 3   37.4739   56.31560  113.0090   64.6530  132.21000   86.71640  102.00100
# 4  315.4460   87.27320  110.3160  145.5600  248.51400  203.88300  277.80300
# 5   90.4331   67.03140  146.3100  195.9530  202.03500  233.70600  179.35900
# 6  319.8010  112.37500  120.9290  181.2150  231.67100  212.11700  180.83500
# 7   60.8476    6.96356   13.6373   10.2541    3.06279    2.31023    8.46771
# 8  275.5220   27.85680   72.8776  100.7330  202.45400  280.07400  178.50100
# 9  323.7120   71.35810  149.2150  137.0080  175.35600  184.87900  157.38800
#
#      Layer8     Layer9   Layer10  ...   Layer33   Layer34   Layer35   Layer36  \
# ...

# %%
EnergyPlotter(new_ele_events)

# %%
bad_ele_list_new = [7]

# %%
new_ele_events.drop(bad_ele_list_new, axis=0, inplace=True)

# %%
new_pion_events = pd.read_csv("run_682_new.csv")

# %%
EnergyPlotter(new_pion_events)

# %%
new_ele_events = pd.concat([new_ele_events, new_pion_events])

# %%
new_ele_events = new_ele_events.reset_index()

# %%
new_ele_events.drop("index", axis=1, inplace = True)

# %%
new_ele_events
# Out:
#         Layer1      Layer2      Layer3      Layer4      Layer5      Layer6  \
# 0   174.251000   54.222700   35.158400   83.384800  188.146000  229.831000
# 1    10.703500   37.767000  110.525000  128.318000  152.580000  172.042000
# 2    32.004000   30.504700   33.832100   33.324500   52.186600   19.965700
# 3    37.473900   56.315600  113.009000   64.653000  132.210000   86.716400
# 4   315.446000   87.273200  110.316000  145.560000  248.514000  203.883000
# 5    90.433100   67.031400  146.310000  195.953000  202.035000  233.706000
# 6   319.801000  112.375000  120.929000  181.215000  231.671000  212.117000
# 7   275.522000   27.856800   72.877600  100.733000  202.454000  280.074000
# 8   323.712000   71.358100  149.215000  137.008000  175.356000  184.879000
# 9     1.872520    0.937405    3.783690    1.028320    3.241290    1.163390
# 10    0.993937    1.590610    1.988700    0.980933    4.694190    2.691050
# ...

# %%
new_ele_events[new_ele_events["Particle"] == "pion"] = new_ele_events[new_ele_events["Particle"] == "pion"].replace(["pion"], ["pion_low"])

# %%
new_ele_events[new_ele_events["Particle"] == "ele"] = new_ele_events[new_ele_events["Particle"] == "ele"].replace(["ele"], ["ele_low"])

# %%
new_ele_events
# Out:
#         Layer1      Layer2      Layer3      Layer4      Layer5      Layer6  \
# 0   174.251000   54.222700   35.158400   83.384800  188.146000  229.831000
# 1    10.703500   37.767000  110.525000  128.318000  152.580000  172.042000
# 2    32.004000   30.504700   33.832100   33.324500   52.186600   19.965700
# 3    37.473900   56.315600  113.009000   64.653000  132.210000   86.716400
# 4   315.446000   87.273200  110.316000  145.560000  248.514000  203.883000
# 5    90.433100   67.031400  146.310000  195.953000  202.035000  233.706000
# 6   319.801000  112.375000  120.929000  181.215000  231.671000  212.117000
# 7   275.522000   27.856800   72.877600  100.733000  202.454000  280.074000
# 8   323.712000   71.358100  149.215000  137.008000  175.356000  184.879000
# 9     1.872520    0.937405    3.783690    1.028320    3.241290    1.163390
# 10    0.993937    1.590610    1.988700    0.980933    4.694190    2.691050
# ...

# %%
df_low_energy = pd.concat([df_low_energy, new_ele_events])

# %%
df_low_energy = df_low_energy.reset_index()

# %%
df_low_energy.drop("index", axis=1, inplace=True)

# %%
df_low_energy["Particle"].value_counts()
# Out:
# ele_low     106
# pion_low    102
# Name: Particle, dtype: int64

# %%
df_low_energy
# Out:
#          Layer1    Layer2      Layer3      Layer4      Layer5      Layer6  \
# 0     19.954700  52.77520  101.591000  137.798000  234.913000  188.128000
# 1     71.055100  70.61160  122.130000  142.446000  216.071000  221.751000
# 2    251.631000  51.29470  126.196000  147.276000  121.490000   89.900500
# 3    181.717000  20.92640   47.591300  111.794000  188.021000  175.041000
# 4    336.465000  20.02800   40.283300   44.239500  101.525000  145.443000
# ..          ...       ...         ...         ...         ...         ...
# 203    1.479250   1.94022    0.712974    3.284470    0.969698    0.820110
# 204    0.833213   1.10872    1.048530    0.943588    7.206630    2.116250
# 205    1.136620   2.70407    1.755330    0.839221    1.157250    0.923178
# 206    2.372410   1.85988    0.968124    0.820238    2.358100    1.169200
# 207   50.862400  38.84730   22.531900   73.037800   64.094200   83.521900
#
#          Layer7     Layer8      Layer9     Layer10  ...   Layer33   Layer34  \
# ...

# %%
df_low_energy.to_csv("df_low_energy_new_events.csv")

# %%
df_high_energy = pd.read_csv("df_submission_new_events.csv")

# %%
df_high_energy.drop(["Unnamed: 0"], axis = 1, inplace=True)

# %%
df_high_energy
# Out:
#         Layer1     Layer2      Layer3      Layer4      Layer5       Layer6  \
# 0     77.66750  259.46000  792.902000  1239.53000  1980.10000  2386.750000
# 1     38.42920  104.51000  371.662000   603.23100  1079.27000  1288.220000
# 2     45.87910   84.95750  234.062000   326.84000   747.98700  1189.420000
# 3    430.59100  361.49100  838.596000  1177.32000  1897.69000  2585.080000
# 4    161.45900   32.52370  215.439000   474.61400  1038.74000  1268.180000
# ..         ...        ...         ...         ...         ...          ...
# 311    0.84950    0.84950    1.980590     2.13522     3.69114     1.062900
# 312   99.14320  396.03000  297.350000   391.45300   760.75600   513.740000
# 313    5.11738    5.11738    1.280890     1.35939     2.17747     0.000000
# 314    1.08453    2.79007    0.833465     1.23524     1.27615     0.897309
# 315    1.92196    1.92196    0.895678     2.91505     2.80681     1.726280
#
# ...

# %%
df_high_energy["Particle"].replace({"ele": "ele_high", "pion": "pion_high"}, inplace=True)

# %%
df_high_energy
# Out:
#         Layer1     Layer2      Layer3      Layer4      Layer5       Layer6  \
# 0     77.66750  259.46000  792.902000  1239.53000  1980.10000  2386.750000
# 1     38.42920  104.51000  371.662000   603.23100  1079.27000  1288.220000
# 2     45.87910   84.95750  234.062000   326.84000   747.98700  1189.420000
# 3    430.59100  361.49100  838.596000  1177.32000  1897.69000  2585.080000
# 4    161.45900   32.52370  215.439000   474.61400  1038.74000  1268.180000
# ..         ...        ...         ...         ...         ...          ...
# 311    0.84950    0.84950    1.980590     2.13522     3.69114     1.062900
# 312   99.14320  396.03000  297.350000   391.45300   760.75600   513.740000
# 313    5.11738    5.11738    1.280890     1.35939     2.17747     0.000000
# 314    1.08453    2.79007    0.833465     1.23524     1.27615     0.897309
# 315    1.92196    1.92196    0.895678     2.91505     2.80681     1.726280
#
# ...

# %%
df_high_and_low = pd.concat([df_high_energy, df_low_energy])

# %%
df_high_and_low.drop("Beam Energy", axis=1, inplace=True)

# %%
df_high_and_low["Particle"].value_counts()
# Out:
# ele_high     109
# ele_low      106
# muon         104
# pion_high    103
# pion_low     102
# Name: Particle, dtype: int64

# %%
df_high_and_low.reset_index(inplace=True)

# %%
df_high_and_low.drop("index", axis=1, inplace=True)

# %%
df_high_and_low
# Out:
#          Layer1     Layer2      Layer3       Layer4       Layer5       Layer6  \
# 0     77.667500  259.46000  792.902000  1239.530000  1980.100000  2386.750000
# 1     38.429200  104.51000  371.662000   603.231000  1079.270000  1288.220000
# 2     45.879100   84.95750  234.062000   326.840000   747.987000  1189.420000
# 3    430.591000  361.49100  838.596000  1177.320000  1897.690000  2585.080000
# 4    161.459000   32.52370  215.439000   474.614000  1038.740000  1268.180000
# ..          ...        ...         ...          ...          ...          ...
# 519    1.479250    1.94022    0.712974     3.284470     0.969698     0.820110
# 520    0.833213    1.10872    1.048530     0.943588     7.206630     2.116250
# 521    1.136620    2.70407    1.755330     0.839221     1.157250     0.923178
# 522    2.372410    1.85988    0.968124     0.820238     2.358100     1.169200
# 523   50.862400   38.84730   22.531900    73.037800    64.094200    83.521900
#
# ...

# %%
df_high_and_low.to_csv("df_high_and_low.csv")
